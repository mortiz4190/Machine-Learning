# %% [markdown]
# <a href="https://colab.research.google.com/github/mortiz4190/Machine-Learning/blob/main/Machine_learning_setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Welcome to Machine Learning!**
#
# Click Text to insert headers
#
# [Example Google Link](https://google.com)

# %%
print('Hello World')
# Out:
# Hello World

# %% [markdown]
# **Adding a code repository using  *!wget*  command**

# %%
# !wget http://databank.worldbank.org/data/download/GDP.csv
# Out:
# --2024-08-22 18:23:09--  http://databank.worldbank.org/data/download/GDP.csv
# Resolving databank.worldbank.org (databank.worldbank.org)... 172.64.145.25, 104.18.42.231, 2606:4700:4400::ac40:9119, ...
# Connecting to databank.worldbank.org (databank.worldbank.org)|172.64.145.25|:80... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://databank.worldbank.org/data/download/GDP.csv [following]
# --2024-08-22 18:23:09--  https://databank.worldbank.org/data/download/GDP.csv
# Connecting to databank.worldbank.org (databank.worldbank.org)|172.64.145.25|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://databankfiles.worldbank.org/public/ddpext_download/GDP.csv [following]
# --2024-08-22 18:23:10--  https://databankfiles.worldbank.org/public/ddpext_download/GDP.csv
# Resolving databankfiles.worldbank.org (databankfiles.worldbank.org)... 13.107.246.66, 2620:1ec:29:1::66
# ...

# %% [markdown]
# ## Importing Pandas library in order to view and do operations on downloaded CSV file.

# %%
import pandas as pd
pd.read_csv('GDP.csv')
# Out:
#     Unnamed: 0 Gross domestic product 2022  Unnamed: 2     Unnamed: 3  \
# 0          NaN                         NaN         NaN            NaN
# 1          NaN                         NaN         NaN            NaN
# 2          NaN                     Ranking         NaN        Economy
# 3          NaN                         NaN         NaN            NaN
# 4          USA                           1         NaN  United States
# ..         ...                         ...         ...            ...
# 324        NaN                         NaN         NaN            NaN
# 325        NaN                         NaN         NaN            NaN
# 326        NaN                         NaN         NaN            NaN
# 327        NaN                         NaN         NaN            NaN
# 328        NaN                         NaN         NaN            NaN
#
#        Unnamed: 4 Unnamed: 5
# 0             NaN        NaN
# 1    (millions of        NaN
# 2     US dollars)        NaN
# ...

# %% [markdown]
# To view first 5 rows, use head() command

# %%
import pandas as pd
pd.read_csv('GDP.csv').head()
# Out:
#   Unnamed: 0 Gross domestic product 2022  Unnamed: 2     Unnamed: 3  \
# 0        NaN                         NaN         NaN            NaN
# 1        NaN                         NaN         NaN            NaN
# 2        NaN                     Ranking         NaN        Economy
# 3        NaN                         NaN         NaN            NaN
# 4        USA                           1         NaN  United States
#
#      Unnamed: 4 Unnamed: 5
# 0           NaN        NaN
# 1  (millions of        NaN
# 2   US dollars)        NaN
# 3           NaN        NaN
# 4   25,462,700         NaN

# %% [markdown]
# To view using tab as a separator *(sep='\t')* in the pd.read_csv() function, as shown below.

# %%
import pandas as pd
pd.read_csv('GDP.csv',sep='\t').head()
# Out:
#        ,Gross domestic product 2022,,,,
# 0                                 ,,,,,
# 1                     ,,,,(millions of,
# 2        ,Ranking,,Economy,US dollars),
# 3                                 ,,,,,
# 4  USA,1,,United States," 25,462,700 ",

# %% [markdown]
# We can also insert links and files into the text area, as well as write formulas.
#
# Formula syntax:
#
# $b^3$
#
# $b = a + b + c$
#
# $b = x/y$
